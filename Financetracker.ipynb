# %%
i = "pemasukan" ; e = "pengeluaran" ; b = "saldo"
i = float(input("Masukkan pemasukan bulan ini:Rp").replace('.', ''))
e = float(input("Masukkan pengeluaran bulan ini:Rp").replace('.', ''))
n = "kebutuhan" ; w = "keinginan" ; s = "tabungan"
n = i*0.5
w = i*0.3
s = i*0.2
print(f"alokasi kebutuhan anda adalah: Rp{n}".replace('.', ''))
print(f"alokasi keinginan anda sejumlah: Rp{w}".replace('.', ''))
print(f"alokasi keinginan anda sejumlah: Rp{s}".replace('.', ''))
b = i - e
print(f"sisa saldo anda adalah Rp{b}".replace('.', ''))
if b > 500000:
    print("saldo aman")
elif b < 500000:
    print("harus hemat!!")
